# %% [markdown]
# <a href="https://colab.research.google.com/github/Khushitz/MACHINE-LEARNING/blob/MACHINE-LEARNING/XGBoost.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **XGBoost**
# ✅ What it is
#
# Extreme Gradient Boosting
#
# One of the most powerful ML algorithms.
#
# Used in:
#
# Kaggle competitions
#
# Industry
#
#
# Intuition
# **bold text**
# Builds trees sequentially.
#
# Each new tree:
#
# Fixes mistakes of previous trees
#
# Very powerful.

# %%
from xgboost import XGBClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris

data = load_iris()

X_train, X_test, y_train, y_test = train_test_split(
    data.data, data.target, test_size=0.2, random_state=42
)


model = XGBClassifier()
model.fit(X_train, y_train)

print(model.score(X_test, y_test))
# Out:
# 1.0
