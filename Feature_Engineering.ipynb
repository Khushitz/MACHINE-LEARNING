# %% [markdown]
# <a href="https://colab.research.google.com/github/Khushitz/MACHINE-LEARNING/blob/MACHINE-LEARNING/Feature_Engineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Feature Engineering =
# Creating better input features from raw data to improve model performance.
#
# In simple words:
#
# **Turning raw data into useful data for the model.**

# %% [markdown]
# hy is it Important?
#
# Because:
#
# Model learns only from features
#
# Bad features → bad model
#
# Good features → simple model works great

# %% [markdown]
# Types of Feature Engineering
#
# We’ll cover:
#
# 1️⃣ Handling Missing Values
# 2️⃣ Encoding Categorical Variables
# 3️⃣ Feature Scaling
# 4️⃣ Creating New Features
# 5️⃣ Feature Selection
# 6️⃣ Feature Transformation
# 7️⃣ Binning
# 8️⃣ Handling Outliers

# %% [markdown]
# ** 1️⃣ Handling Missing Values**
# Why
# Most models can’t handle NaN.
#
# Options
#
# Drop rows
#
# Fill with mean/median
#
# Fill with mode
#
# Fill with **constant**
#
#
#
# **SimpleImputer**, which provides basic strategies for imputing missing values.
# Strategy: The 'mean' strategy is specified, meaning missing values will be replaced by the average value of their respective columns.
# Action: The code fits the imputer to the data and transforms the dataset X by imputing the missing values.

# %%
from sklearn.impute import SimpleImputer
import numpy as np

imputer = SimpleImputer(strategy='mean')
X = imputer.fit_transform(X)

# %% [markdown]
# Encoding Categorical Variables
# **bold text**
# Models understand numbers, not text

# %% [markdown]
# **Label Encoding:** Converts categorical text data into numerical labels (e.g., mapping "red", "blue" to 0, 1).
# **One Hot Encoding:** Creates binary columns for each category, which is often preferred for machine learning models to prevent implying an order between categories.

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['Color'] = le.fit_transform(df['Color'])

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(sparse=False)
encoded = encoder.fit_transform(df[['Color']])

# %% [markdown]
# | Model               | Needs Feature Engineering? |
# | ------------------- | -------------------------- |
# | Logistic Regression | YES                        |
# | SVM                 | YES                        |
# | KNN                 | YES                        |
# | Random Forest       | Less                       |
# | XGBoost             | Less                       |

# %% [markdown]
# Tree-based models are more automatic.
#
# Linear models need more engineering.
